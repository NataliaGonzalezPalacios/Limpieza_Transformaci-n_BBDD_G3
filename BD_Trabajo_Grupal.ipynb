# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Se carga la base de datos analizar en un dataframe

# %%
from pandas.io.excel import read_excel

url ="https://raw.githubusercontent.com/Neo3009/BasesdeDatosgrupo2/main/HOW_2FTE_SEX_JOB_NB_A-filtrado-2023-03-23.csv"
df = pd.read_csv(url)
df
# Out:
#      ref_area.label                                    indicator.label  \
# 0        Afganistán  Horas de trabajo perdidas debido a la crisis d...
# 1        Afganistán  Horas de trabajo perdidas debido a la crisis d...
# 2            Angola  Horas de trabajo perdidas debido a la crisis d...
# 3            Angola  Horas de trabajo perdidas debido a la crisis d...
# 4            Angola  Horas de trabajo perdidas debido a la crisis d...
# ...             ...                                                ...
# 2791       Zimbabwe  Horas de trabajo perdidas debido a la crisis d...
# 2792       Zimbabwe  Horas de trabajo perdidas debido a la crisis d...
# 2793       Zimbabwe  Horas de trabajo perdidas debido a la crisis d...
# 2794       Zimbabwe  Horas de trabajo perdidas debido a la crisis d...
# 2795       Zimbabwe  Horas de trabajo perdidas debido a la crisis d...
#
#                       source.label    sex.label  \
# 0     OIT - Estimaciones Modeladas  Sexo: Total
# ...

# %% [markdown]
# Se valida las columnas existentes

# %%
df.columns
# Out:
# Index(['ref_area.label', 'indicator.label', 'source.label', 'sex.label',
#        'classif1.label', 'time', 'obs_value'],
#       dtype='object')

# %%
La variable que nos interesa validamos datos unicos

# %%
df.columns=['ref_area.label', 'indicator.label', 'source.label', 'sex.label', 'classif1.label', 'time', 'obs_value']
df['ref_area.label'].unique()
# Out:
# array(['Afganistán', 'Angola', 'Albania', 'Emiratos Arabes Unidos',
#        'Argentina', 'Armenia', 'Australia', 'Austria', 'Azerbaiyán',
#        'Burundi', 'Bélgica', 'Benin', 'Burkina Faso', 'Bangladesh',
#        'Bulgaria', 'Bahrein', 'Bahamas', 'Bosnia y Herzegovina',
#        'Belarús', 'Belice', 'Bolivia', 'Brasil', 'Barbados',
#        'Brunei Darussalam', 'Bhután', 'Botswana',
#        'República Centroafricana', 'Canadá', 'Islas Anglonormandas',
#        'Suiza', 'Chile', 'China', "Côte d'Ivoire", 'Camerún',
#        'Congo, Rep. Dem. del', 'Congo', 'Colombia', 'Comoras',
#        'Cabo Verde', 'Costa Rica', 'Cuba', 'Chipre', 'Chequia',
#        'Alemania', 'Djibouti', 'Dinamarca', 'República Dominicana',
#        'Argelia', 'Ecuador', 'Egipto', 'Eritrea', 'Sahara Occidental',
#        'España', 'Estonia', 'Etiopía', 'Finlandia', 'Fiji', 'Francia',
#        'Gabón', 'Reino Unido', 'Georgia', 'Ghana', 'Guinea', 'Gambia',
# ...

# %%
Se realiza el filtro por los paises que se requiere

# %%
filtro= df['ref_area.label'].isin(['Argentina', 'Bahamas',
'Belice',
'Bolivia',
'Brasil',
'Barbados',
'Chile',
'Colombia',
'Cuba',
'Ecuador',
'Guatemala',
'Guyana',
'Honduras',
'Haití',
'Jamaica',
'México',
'Nicaragua',
'Panamá',
'Perú',
'Paraguay',
'Suriname',
'Uruguay',
'Venezuela',
'América Latina y el Caribe',
'América Latina y el Caribe: Ingresomedianobajo',
'América Latina y el Caribe: Ingresomedianoalto',
'América Latina y el Caribe: Ingresoalto',
'Caribe',
'América Central',
'América del Sur'])
print(filtro)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2791    False
# 2792    False
# 2793    False
# 2794    False
# 2795    False
# Name: ref_area.label, Length: 2796, dtype: bool

# %%
Se genera el dataframe con el filtro realizado con anterioridad

# %%
df_filtrado = df.loc[filtro]
df_filtrado
# Out:
#        ref_area.label                                    indicator.label  \
# 26          Argentina  Horas de trabajo perdidas debido a la crisis d...
# 27          Argentina  Horas de trabajo perdidas debido a la crisis d...
# 28          Argentina  Horas de trabajo perdidas debido a la crisis d...
# 29          Argentina  Horas de trabajo perdidas debido a la crisis d...
# 30          Argentina  Horas de trabajo perdidas debido a la crisis d...
# ...               ...                                                ...
# 1927  América del Sur  Horas de trabajo perdidas debido a la crisis d...
# 1928  América del Sur  Horas de trabajo perdidas debido a la crisis d...
# 1929  América del Sur  Horas de trabajo perdidas debido a la crisis d...
# 1930  América del Sur  Horas de trabajo perdidas debido a la crisis d...
# 1931  América del Sur  Horas de trabajo perdidas debido a la crisis d...
#
#                       source.label      sex.label  \
# ...

# %% [markdown]
# Filtro de una sola variable

# %%
#Filtrar los registros de Latinoamerica y generar base final
df1 = df.loc[df["ref_area.label"] == ('América Latina y el Caribe')]
df1
# Out:
#                   ref_area.label  \
# 1820  América Latina y el Caribe
# 1821  América Latina y el Caribe
# 1822  América Latina y el Caribe
# 1823  América Latina y el Caribe
# 1824  América Latina y el Caribe
# 1825  América Latina y el Caribe
# 1826  América Latina y el Caribe
# 1827  América Latina y el Caribe
# 1828  América Latina y el Caribe
# 1829  América Latina y el Caribe
# 1830  América Latina y el Caribe
# 1831  América Latina y el Caribe
# 1832  América Latina y el Caribe
# 1833  América Latina y el Caribe
# 1834  América Latina y el Caribe
# 1835  América Latina y el Caribe
#
#                                         indicator.label  \
# 1820  Horas de trabajo perdidas debido a la crisis d...
# 1821  Horas de trabajo perdidas debido a la crisis d...
# 1822  Horas de trabajo perdidas debido a la crisis d...
# 1823  Horas de trabajo perdidas debido a la crisis d...
# 1824  Horas de trabajo perdidas debido a la crisis d...
# ...
